# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikitaanand22/Calculator.py/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("nikita")
# Out:
# nikita

# %%
a=1
b=7
print(a+b)
# Out:
# 8

# %%
a=int(input())
b=int(input())
print(a+b)

# %%
p=int(input())
if(p%2==0)
  print("even")
