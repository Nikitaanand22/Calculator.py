# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikitaanand22/Calculator.py/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("IIT PATNA")
# Out:
# IIT PATNA

# %%
print("hello world")
# Out:
# hello world

# %%
print(" nikita is my name.","my age is 18.")
# Out:
#  nikita is my name. my age is 18.

# %%
print("22")
# Out:
# 22

# %%
print(23+22)
# Out:
# 45

# %%
name =" nikita"
age = 18
price = 26.5
print(name)
print( age)
print(price)
print(type(name))
print(type(age))
print(type(price))
# Out:
#  nikita
# 18
# 26.5
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
name1 = "NP"
name2 = '"NP"'
name3 = 'NP'
print( name1)
print( name2)
print(name3)
# Out:
# NP
# "NP"
# NP

# %%
print("22+23")
# Out:
# 22+23

# %%
print("2*3")
# Out:
# 2*3

# %%
print(29*68)
# Out:
# 1972
